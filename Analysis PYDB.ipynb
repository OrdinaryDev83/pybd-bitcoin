# %%
# !pip install pandas==1.5.3 matplotlib==3.7 plotly==5.13.1

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import glob
import dateutil.parser
import os
import datetime

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Requirement already satisfied: matplotlib==3.7 in /usr/local/lib/python3.9/dist-packages (3.7.0)
# Requirement already satisfied: plotly==5.13.1 in /usr/local/lib/python3.9/dist-packages (5.13.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.5.3) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas==1.5.3) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib==3.7) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly==5.13.1) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib==3.7) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.15.0)

# %%
# !git clone --depth 1 https://github.com/Yquetzal/DefiEGC2024.git
# %cd DefiEGC2024
# Out:
# Cloning into 'DefiEGC2024'...
# remote: Enumerating objects: 925, done.
# remote: Counting objects: 100% (925/925), done.
# remote: Compressing objects: 100% (925/925), done.
# remote: Total 925 (delta 0), reused 923 (delta 0), pack-reused 0
# Receiving objects: 100% (925/925), 64.96 MiB | 10.42 MiB/s, done.
# Updating files: 100% (920/920), done.
# /content/DefiEGC2024/DefiEGC2024/DefiEGC2024

# %% [markdown]
# ## About Dataset
#
# * Time Series
#   * df_global - *contains the number of transactions, payments, blocks, received and sent satoshis, fee statistics, miners reward, created coins, auto transaction*
#   * df_actors - *data on 100 most active actors (per activity day) such as its identity, data on received and spent satoshis, data of fee paid, auto transactions*
#   * df_external - *bitcoin price (USD) and hash rate*
# * Transaction Networks
#   * df_network - *network of transactions per day in the format source actor, target actor, total value and number of transactions*

# %% [markdown]
# ## Global

# %% [markdown]
# We are going to read the csv file.
# 1. Check types of values
# 2. Remove unnecessary columns and rows
# 3. Treat the Nulls
# 4. Treat the duplicates

# %%
df_global = pd.read_csv("timeseries/global.csv", index_col=0, parse_dates=True).sort_index()
df_global.drop(labels=["year", "month", "day"], axis=1, inplace=True)

# %%
df_global.head()
# Out:
#              total_fee  total_received_satoshi  total_sent_satoshi  \
# 2015-01-01   801373971          45473028339385      45058028339385
# 2015-01-02  1159934218          73370568521080      72955568521080
# 2015-01-03  1196476043          82635189454578      82220189454578
# 2015-01-04  2159195328         115159442449532     114726942449532
# 2015-01-05  1608443040         112439228285641     112051728285641
#
#             mean_fee_satoshi   mean_feeUSD  mean_fee_for100  nb_transactions  \
# 2015-01-01      13609.829337  4.284054e+06         0.799999            58882
# 2015-01-02      14978.682808  4.732406e+06         0.778933            77439
# 2015-01-03      14304.385766  4.086009e+06         0.797419            83644
# 2015-01-04      25138.199015  6.619757e+06         0.899054            85893
# 2015-01-05      16955.609622  4.662858e+06         0.898594            94862
#
#             nb_payments  mean_nb_inputs  mean_nb_outputs  nb_mining  \
# 2015-01-01       161194        2.595241         2.737577        166
# 2015-01-02       257633        2.715557         3.326915        166
# 2015-01-03       295618        2.781885         3.534240        166
# 2015-01-04       280288        2.770133         3.263223        173
# 2015-01-05       286552        2.954471         3.020725        155
#
#             total_mining_satoshi  newly_created_coins  self_spent_satoshi  \
# 2015-01-01          415801373971         415000000000       2757774885900
# 2015-01-02          416159934218         415000000000       4316724676318
# 2015-01-03          416196476043         415000000000       5584584356557
# 2015-01-04          434659195328         432500000000       6554587956125
# 2015-01-05          389108443040         387500000000       5063695492444
#
#              total_received  volume_without_self
# 2015-01-01   45473028339385       42715253453485
# 2015-01-02   73370568521080       69053843844762
# 2015-01-03   82635189454578       77050605098021
# 2015-01-04  115159442449532      108604854493407
# 2015-01-05  112439228285641      107375532793197

# %% [markdown]
# Next, we check dtype of the index in order to do operation on datetime and the type of other columns.

# %%
df_global.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df_global.dtypes
# Out:
# total_fee                   int64
# total_received_satoshi      int64
# total_sent_satoshi          int64
# mean_fee_satoshi          float64
# mean_feeUSD               float64
# mean_fee_for100           float64
# nb_transactions             int64
# nb_payments                 int64
# mean_nb_inputs            float64
# mean_nb_outputs           float64
# nb_mining                   int64
# total_mining_satoshi        int64
# newly_created_coins         int64
# self_spent_satoshi          int64
# total_received              int64
# volume_without_self         int64
# dtype: object

# %% [markdown]
# We are checking if they are some missing values in the global.csv dataframe.

# %%
df_global.isnull().values.any()
# Out:
# False

# %% [markdown]
# No null value were found. Now, we check if they are duplicates in the dataframe.

# %%
df_global.duplicated().any()
# Out:
# False

# %% [markdown]
# It seems no duplicated values were found in the dataframe. We will repeat the same action for the other dataframes.

# %% [markdown]
# ## External

# %%
df_external = pd.read_csv("timeseries/external.csv", index_col="date", usecols=["date", "PriceUSD", "HashRate"], parse_dates=True).sort_index()

# %%
df_external.head()
# Out:
#               PriceUSD       HashRate
# date
# 2015-01-02  315.942732  333345.017260
# 2015-01-03  285.647310  327284.198765
# 2015-01-04  263.334575  347486.927083
# 2015-01-05  275.003852  315162.561773
# 2015-01-06  287.549521  319203.107437

# %%
df_external.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df_external.dtypes
# Out:
# PriceUSD    float64
# HashRate    float64
# dtype: object

# %%
df_external.isnull().values.any()
# Out:
# False

# %%
df_external.duplicated().any()
# Out:
# False

# %% [markdown]
# ## Blockchain by actors
#
# We repeat the same step one more time for the block_chain_by_actor dataframe.

# %%
df_actors = pd.read_csv("timeseries/blockchain_by_actor.csv", index_col=0, parse_dates=['date']).sort_index()
df_actors.drop(labels=["year", "month", "day"], axis=1, inplace=True)
df_actors["identity"] = df_actors["identity"].astype(pd.StringDtype())

# %%
df_actors.head()
# Out:
#            identity      received  nb_received       date   sum_fee  \
# 0    HappyCoins.com  1.377590e+09          4.0 2015-01-01   49596.0
# 1               821  2.476057e+09          5.0 2015-01-01   10000.0
# 2   FortuneJack.com  1.201470e+08         29.0 2015-01-01   83000.0
# 3               396  1.906135e+10         70.0 2015-01-01  540000.0
# 4  SatoshiMines.com  7.401319e+08        193.0 2015-01-01  740000.0
#
#    mean_fee_for100  nb_transactions          sent  self_spent  \
# 0         0.004957              4.0  1.277500e+09         0.0
# 1         0.000851              1.0  1.174552e+09         0.0
# 2         0.194670             11.0  1.541127e+08  14158970.0
# 3         0.023738             54.0  1.842989e+10         0.0
# 4         0.447934             45.0  1.813624e+09  35044568.0
#
#    self_spent_estimated  nb_spent         spent
# 0                   0.0       8.0  1.277500e+09
# 1                   0.0       2.0  1.174552e+09
# 2            14158970.0      22.0  1.399538e+08
# 3                   0.0     108.0  1.842989e+10
# 4            35044568.0      84.0  1.778579e+09

# %%
df_actors.index.dtype
# Out:
# dtype('int64')

# %%
df_actors.dtypes
# Out:
# identity                        string
# received                       float64
# nb_received                    float64
# date                    datetime64[ns]
# sum_fee                        float64
# mean_fee_for100                float64
# nb_transactions                float64
# sent                           float64
# self_spent                     float64
# self_spent_estimated           float64
# nb_spent                       float64
# spent                          float64
# dtype: object

# %%
df_actors.isnull().values.any()
# Out:
# False

# %%
df_actors.duplicated().any()
# Out:
# False

# %% [markdown]
# ## Network

# %%
df_network = pd.DataFrame()

dfs = []

for file_path in glob.glob("networks/*"):
    date = os.path.splitext(os.path.basename(os.path.normpath(file_path)))[0]
    date = dateutil.parser.parse(date)

    df_temp = pd.read_csv(file_path)
    df_temp['date'] = date
    # set index to be date and hour
    df_temp.set_index(['date'], inplace=True)
    dfs.append(df_temp)

df_network = pd.concat(dfs, axis=0)

df_network["Source"] = df_network["Source"].astype(pd.StringDtype())
df_network["Target"] = df_network["Target"].astype(pd.StringDtype())

df_network
# Out:
#                         Source                  Target       value  \
# date
# 2015-11-30            50658390  ePay.info_CoinJoinMess     1257822
# 2015-11-30  Genesis-Mining.com                     833   198820904
# 2015-11-30             1228047                   51014    48775876
# 2015-11-30           Huobi.com                     331  6723075345
# 2015-11-30                 578   MercadoBitcoin.com.br    18834000
# ...                        ...                     ...         ...
# 2016-09-24                   0                    2803   112798719
# 2016-09-24     SatoshiDice.com            Poloniex.com     4363036
# 2016-09-24               50354                   52030    84386800
# 2016-09-24             1577580              BitPay.com     6343157
# 2016-09-24                   4                     942    13130279
#
#             nb_transactions
# date
# 2015-11-30                2
# 2015-11-30                2
# 2015-11-30                1
# 2015-11-30               10
# 2015-11-30                1
# ...                     ...
# 2016-09-24                1
# 2016-09-24                2
# 2016-09-24                1
# 2016-09-24                1
# 2016-09-24                1
#
# [5876734 rows x 4 columns]

# %%
df_network.head()
# Out:
#                         Source                  Target       value  \
# date
# 2015-11-30            50658390  ePay.info_CoinJoinMess     1257822
# 2015-11-30  Genesis-Mining.com                     833   198820904
# 2015-11-30             1228047                   51014    48775876
# 2015-11-30           Huobi.com                     331  6723075345
# 2015-11-30                 578   MercadoBitcoin.com.br    18834000
#
#             nb_transactions
# date
# 2015-11-30                2
# 2015-11-30                2
# 2015-11-30                1
# 2015-11-30               10
# 2015-11-30                1

# %%
df_network.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df_network.dtypes
# Out:
# Source             string
# Target             string
# value               int64
# nb_transactions     int64
# dtype: object

# %%
df_network.isnull().values.any()
# Out:
# False

# %%
df_network.reset_index().duplicated().any()
# Out:
# False

# %% [markdown]
# Actors Analysis

# %%
from plotly.subplots import make_subplots

df_diff = df_actors.copy()
df_diff["diff"] = df_diff["received"] - df_diff["spent"]

fig = px.line(df_diff, x='date', y='diff', line_group="identity", color='identity')
# second bitcoin halving in 2016
fig.add_vline(x=datetime.datetime(2016, 7, 9), line_width=1, line_color="red")

# Add figure title
fig.update_layout(
    title_text="Difference by Identity"
)

fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
best_range = np.abs(df_diff["diff"]).quantile(0.99).min()
print(best_range)

df_outliers = df_diff[np.abs(df_diff["diff"]) > best_range]
df_outliers["diff"] = df_outliers["diff"] / 10e8
# Out:
# 1928240716261.786
# <ipython-input-202-63d5501b70a8>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.scatter(df_outliers, x='date', y='diff', color='identity', size="nb_transactions")
# second bitcoin halving in 2016
fig.add_vline(x=datetime.datetime(2016, 7, 9), line_width=1, line_color="red")

# Add figure title
fig.update_layout(
    title_text="Outliers by Identity"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1b1cceaf-a9af-4ffa-b400-38f8cc7b0ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b1cceaf-a9af-4ffa-b400-38f8cc7b0ea8")) {                    Plotly.newPlot(                        "1b1cceaf-a9af-4ffa-b400-38f8cc7b0ea8",                        [{"hovertemplate":"identity=Bitstamp.net<br>date=%{x}<br>diff=%{y}<br>nb_transactions=%{marker.size}<extra></extra>","legendgroup":"Bitstamp.net","marker":{"color":"#636efa","size":[63.0,184.0,141.0,118.0,158.0,136.0,148.0,204.0,132.0,168.0],"sizemode":"area","sizeref":20.7425,"symbol":"circle"},"mode":"markers","name":"Bitstamp.net","orientation":"v","showlegend":true,"x":["2015-01-11T00:00:00","2015-01-14T00:00:00","2015-08-05T00:00:00","2015-08-08T00:00:00","2015-09-10T00:00:00","2015-09-16T00:00:00","2015-10-17T00:00:00","2015-10-30T00:00:00","2016-02-26T00:00:00","2017-04-14T00:00:00"],"xaxis":"x","y":[2304.569644216,2041.326393124,3021.487188809,3883.121875651,2615.496051093,2082.327289082,5170.608123774,2138.982251771,3400.072076719,2333.759899572],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=Huobi.com<br>date=%{x}<br>diff=%{y}<br>nb_transactions=%{marker.size}<extra></extra>","legendgroup":"Huobi.com","marker":{"color":"#EF553B","size":[268.0,312.0,332.0,250.0,302.0,409.0,340.0,2627.0,3135.0,4034.0,4201.0,4944.0,5792.0,6789.0,1758.0,3146.0,2765.0,2849.0,3033.0,1375.0,2381.0,4537.0,6095.0,3370.0,2449.0,2362.0,3133.0,4054.0,3105.0,2418.0,1598.0,1939.0,2596.0,1023.0,1094.0],"sizemode":"area","sizeref":20.7425,"symbol":"circle"},"mode":"markers","name":"Huobi.com","orientation":"v","showlegend":true,"x":["2015-06-19T00:00:00","2015-07-05T00:00:00","2015-07-28T00:00:00","2015-08-02T00:00:00","2015-09-06T00:00:00","2015-09-19T00:00:00","2015-09-20T00:00:00","2015-11-03T00:00:00","2015-11-04T00:00:00","2015-11-05T00:00:00","2015-11-09T00:00:00","2015-12-02T00:00:00","2015-12-05T00:00:00","2016-05-28T00:00:00","2016-05-31T00:00:00","2016-06-09T00:00:00","2016-06-13T00:00:00","2016-06-15T00:00:00","2016-06-22T00:00:00","2016-07-06T00:00:00","2016-09-25T00:00:00","2016-09-29T00:00:00","2016-10-08T00:00:00","2016-10-11T00:00:00","2016-10-16T00:00:00","2016-10-17T00:00:00","2016-10-18T00:00:00","2016-10-19T00:00:00","2016-11-03T00:00:00","2016-11-26T00:00:00","2016-11-28T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00"],"xaxis":"x","y":[2034.661637712,2799.877899339,1929.796147473,1966.303922885,2545.061326081,3033.159482108,2428.713742322,2107.5904351,3301.463680368,2759.284619115,2348.978521884,1966.981565554,2612.621447361,2100.952423428,2074.767799135,4964.566312177,2623.579947479,3121.978728421,2731.190386753,2052.566297607,8792.942402528,1958.075641217,2748.596633939,2094.681550638,2857.190791689,2904.240034764,5177.61840631,2368.815007382,2125.25492265,5729.452619324,2069.911570552,3333.810017467,3748.729292391,3391.833298751,2918.551421484],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=0<br>date=%{x}<br>diff=%{y}<br>nb_transactions=%{marker.size}<extra></extra>","legendgroup":"0","marker":{"color":"#00cc96","size":[1148.0,8297.0],"sizemode":"area","sizeref":20.7425,"symbol":"circle"},"mode":"markers","name":"0","orientation":"v","showlegend":true,"x":["2015-06-19T00:00:00","2017-03-25T00:00:00"],"xaxis":"x","y":[2280.337793241,3035.877057325],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=Xapo.com<br>date=%{x}<br>diff=%{y}<br>nb_transactions=%{marker.size}<extra></extra>","legendgroup":"Xapo.com","marker":{"color":"#ab63fa","size":[573.0,663.0,931.0,1160.0,1152.0,1468.0,1241.0,1170.0,1319.0,1243.0,1332.0,3923.0],"sizemode":"area","sizeref":20.7425,"symbol":"circle"},"mode":"markers","name":"Xapo.com","orie ...

# %%
df_outliers["Profit / Transaction / Day"] = df_outliers["diff"] / df_outliers["nb_transactions"]
df_outliers = df_outliers.rename(columns={"date" : "Date"})

fig = px.scatter(df_outliers, x='Date', y='Profit / Transaction / Day', color='identity')
# second bitcoin halving in 2016
fig.add_vline(x=datetime.datetime(2016, 7, 9), line_width=1, line_color="red")

# Add figure title
fig.update_layout(
    title_text="Outliers in Daily Profit in Bitcoin by Identity"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="34b94638-ed78-4e69-8358-86a1c559c30f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34b94638-ed78-4e69-8358-86a1c559c30f")) {                    Plotly.newPlot(                        "34b94638-ed78-4e69-8358-86a1c559c30f",                        [{"hovertemplate":"identity=Bitstamp.net<br>Date=%{x}<br>Profit / Transaction / Day=%{y}<extra></extra>","legendgroup":"Bitstamp.net","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bitstamp.net","orientation":"v","showlegend":true,"x":["2015-01-11T00:00:00","2015-01-14T00:00:00","2015-08-05T00:00:00","2015-08-08T00:00:00","2015-09-10T00:00:00","2015-09-16T00:00:00","2015-10-17T00:00:00","2015-10-30T00:00:00","2016-02-26T00:00:00","2017-04-14T00:00:00"],"xaxis":"x","y":[36.58047054311111,11.09416518002174,21.42898715467376,32.90781250551695,16.55377247527215,15.31123006677941,34.93654137685135,10.48520711652451,25.758121793325756,13.891427973642857],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=Huobi.com<br>Date=%{x}<br>Profit / Transaction / Day=%{y}<extra></extra>","legendgroup":"Huobi.com","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Huobi.com","orientation":"v","showlegend":true,"x":["2015-06-19T00:00:00","2015-07-05T00:00:00","2015-07-28T00:00:00","2015-08-02T00:00:00","2015-09-06T00:00:00","2015-09-19T00:00:00","2015-09-20T00:00:00","2015-11-03T00:00:00","2015-11-04T00:00:00","2015-11-05T00:00:00","2015-11-09T00:00:00","2015-12-02T00:00:00","2015-12-05T00:00:00","2016-05-28T00:00:00","2016-05-31T00:00:00","2016-06-09T00:00:00","2016-06-13T00:00:00","2016-06-15T00:00:00","2016-06-22T00:00:00","2016-07-06T00:00:00","2016-09-25T00:00:00","2016-09-29T00:00:00","2016-10-08T00:00:00","2016-10-11T00:00:00","2016-10-16T00:00:00","2016-10-17T00:00:00","2016-10-18T00:00:00","2016-10-19T00:00:00","2016-11-03T00:00:00","2016-11-26T00:00:00","2016-11-28T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00"],"xaxis":"x","y":[7.592021036238806,8.973967626086539,5.812638998412651,7.86521569154,8.427355384374172,7.4160378535647915,7.143275712711765,0.8022803331176246,1.0530984626373205,0.6840070944757065,0.559147470098548,0.3978522584049353,0.4510741449172997,0.30946419552629256,1.1801864613964734,1.5780566790136683,0.9488535072256782,1.0958156294914005,0.9004913902911309,1.492775489168727,3.692961949822764,0.43157937871214463,0.4509592508513536,0.6215672257086053,1.1666765176353613,1.2295681772921254,1.6526072155473988,0.5843154926941293,0.6844621328985507,2.3695006696956162,1.2953138739374217,1.7193450322160906,1.4440405594726502,3.315575072092864,2.6677800927641684],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=0<br>Date=%{x}<br>Profit / Transaction / Day=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"0","orientation":"v","showlegend":true,"x":["2015-06-19T00:00:00","2017-03-25T00:00:00"],"xaxis":"x","y":[1.9863569627534843,0.3659005733789321],"yaxis":"y","type":"scatter"},{"hovertemplate":"identity=Xapo.com<br>Date=%{x}<br>Profit / Transaction / Day=%{y}<extra></extra>","legendgroup":"Xapo.com","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Xapo.com","orientation":"v","showlegend":true,"x":["2015-08-09T00:00:00","2015-08-10T00:00:00","2015-10-07T00:00:00","2015-10-21T00:00:00","2015-10-28T00:00:00","2015-11-03T00:00:00","2015-11-05T00:00:00","2015-11-27T00:00:00","2015-12-19T00:00:00","2015-12-31T00:00:00","2016-03-01T00:00:00","2016-05-17T00:00:00"],"xaxis":"x","y":[12.022509910979059,-3.3003832224177976,3.4386806348270675,1.7286214035112069,1.8342650813550345,1.412986270617166,5.20516279178162 ...

# %%
df_network = df_network.reset_index()

# %%
# select transactions with target Xapo.com from network from August 9 2015

df_transactions_xapo_in = df_network.loc[(df_network["Target"] == "Xapo.com") & (df_network["date"] == datetime.datetime(2015, 8, 9))]
df_transactions_xapo_out = df_network.loc[(df_network["Source"] == "Xapo.com") & (df_network["date"] == datetime.datetime(2015, 8, 9))]
df_transactions_xapo_out = df_transactions_xapo_out.rename(columns={'Source': 'Target', 'Target': 'Source'})
df_transaction_total = df_transactions_xapo_in.copy()
df_transaction_total = df_transactions_xapo_in.join(df_transactions_xapo_out.set_index(['Source', 'Target']), on=['Source', 'Target'], rsuffix='_out')
df_transaction_total
# Out:
#              date               Source    Target        value  \
# 135380 2015-08-09           Bitcoin.de  Xapo.com   1321941223
# 135424 2015-08-09             73413077  Xapo.com     66483404
# 135536 2015-08-09                  354  Xapo.com  28509266642
# 135560 2015-08-09                 1567  Xapo.com      1292500
# 135572 2015-08-09  HolyTransaction.com  Xapo.com     11614217
# ...           ...                  ...       ...          ...
# 139773 2015-08-09                  417  Xapo.com     22174418
# 139979 2015-08-09                 3368  Xapo.com   4238592856
# 140014 2015-08-09        PrimeDice.com  Xapo.com     10045756
# 140049 2015-08-09         AnoniBet.com  Xapo.com      2250000
# 140070 2015-08-09             73096754  Xapo.com     11970000
#
#         nb_transactions   date_out     value_out  nb_transactions_out
# 135380                1 2015-08-09  7.102574e+07                  2.0
# 135424                2        NaT           NaN                  NaN
# 135536               29        NaT           NaN                  NaN
# 135560                1        NaT           NaN                  NaN
# 135572                8 2015-08-09  9.378714e+11                 46.0
# ...                 ...        ...           ...                  ...
# 139773                1        NaT           NaN                  NaN
# 139979               82 2015-08-09  1.149555e+08                  2.0
# 140014                4 2015-08-09  4.590141e+08                 26.0
# 140049                1 2015-08-09  1.300533e+07                  1.0
# 140070                3        NaT           NaN                  NaN
#
# [70 rows x 8 columns]
